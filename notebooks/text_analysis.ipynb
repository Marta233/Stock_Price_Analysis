# %%
import pandas as pd
import sys 
import yfinance as yf
sys.path.insert(0, '/10 A KAI 2/week 1/Stock_Price_Analysis/')

# %%
from src.text_analysis import TextAnalyzer
from src.Descrip_anal import Descriptives
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# * Read news data

# %%
df = pd.read_csv('../data/raw_analyst_ratings.csv', index_col=0)

# %%
result = TextAnalyzer(df)

# %% [markdown]
# ##### Do sentiment analysis on the headline col after removing stopwords

# %%
result.sentiment_analysis()
# Out:
#                                             headline  \
# 0            Stocks That Hit 52-Week Highs On Friday
# 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                      71 Biggest Movers From Friday
# 3       46 Stocks Moving In Friday's Mid-Day Session
# 4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  \
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# 2  2020-05-26 04:30:07-04:00     A
# 3  2020-05-22 12:45:06-04:00     A
# 4  2020-05-22 11:38:59-04:00     A
#
#                                     cleaned_headline sentiment  polarity
# 0                    stocks hit 52 week highs friday   Neutral       0.0
# 1                 stocks hit 52 week highs wednesday   Neutral       0.0
# 2                           71 biggest movers friday   Neutral       0.0
# 3            46 stocks moving friday mid day session   Neutral       0.0
# 4  b securities maintains neutral agilent technol...   Neutral       0.0

# %% [markdown]
# ##### extract top 10 keywords from the headline in word lavel using TFIDF and bigram lavel

# %%
wor, big = result.keyword_extraction()

# %%
wor
# Out:
#     Keyword   TF-IDF Score
# 0  earnings   78328.184675
# 1       eps   62401.313224
# 2       est   53859.726234
# 3    market   94797.566144
# 4   reports   64795.431428
# 5     sales   47344.869661
# 6    shares   93176.130946
# 7    stocks  149539.632769
# 8    update   75366.829457
# 9        vs   65826.306491

# %%
big
# Out:
#                   Bigram  Count
# 0               (eps, 0)  83791
# 1             (52, week)  51006
# 2                (vs, 0)  47735
# 3        (price, target)  47274
# 4        (benzinga, top)  44259
# 5       (stocks, moving)  40032
# 6             (mid, day)  37324
# 7       (market, update)  33101
# 8  (earnings, scheduled)  32054
# 9  (initiates, coverage)  28993

# %%
big['Bigram']=big['Bigram'].apply(lambda x: ' '.join(x))

# %%
big
# Out:
#                Bigram  Count
# 0               eps 0  83791
# 1             52 week  51006
# 2                vs 0  47735
# 3        price target  47274
# 4        benzinga top  44259
# 5       stocks moving  40032
# 6             mid day  37324
# 7       market update  33101
# 8  earnings scheduled  32054
# 9  initiates coverage  28993

# %% [markdown]
# ##### plot extracted top word and bigram word using bar graph

# %%
result.plot_keyword_extraction(wor,big)

# %% [markdown]
# ##### filtered email as a publisher name and filter the domain from the email

# %%
result.filter_publishers_with_email()
# Out:
#                                                   headline  \
# 5        CFRA Maintains Hold on Agilent Technologies, L...
# 6        UBS Maintains Neutral on Agilent Technologies,...
# 8        Wells Fargo Maintains Overweight on Agilent Te...
# 11       SVB Leerink Maintains Outperform on Agilent Te...
# 22       UBS Maintains Neutral on Agilent Technologies,...
# ...                                                    ...
# 1410564  Based on Options Pricing, Here's 5 Companies' ...
# 1410565  ZNGA (Implied Move): 3.50 Straddle Price is $0...
# 1411299  Zoe's Kitchen Shares Indicated Up 1% Premarket...
# 1412846  Zumiez Sees FY20 EPS $0.01-$0.07 vs $0.08 Est....
# 1412847  Zumiez Q4 EPS $1.48 Beats $1.36 Estimate, Sale...
#
#                                                        url  \
# 5        https://www.benzinga.com/news/20/05/16095163/c...
# 6        https://www.benzinga.com/news/20/05/16094027/u...
# 8        https://www.benzinga.com/news/20/05/16093505/w...
# 11       https://www.benzinga.com/news/20/05/16092270/s...
# 22       https://www.benzinga.com/news/20/04/15897306/u...
# ...                                                    ...
# 1410564  https://www.benzinga.com/markets/options/13/04...
# 1410565  https://www.benzinga.com/markets/options/13/04...
# 1411299  https://www.benzinga.com/news/18/08/12237400/z...
# 1412846  https://www.benzinga.com/news/20/03/15541915/z...
# 1412847  https://www.benzinga.com/news/earnings/20/03/1...
#
#                          publisher                       date stock  \
# 5          vishwanath@benzinga.com  2020-05-22 11:23:25-04:00     A
# 6          vishwanath@benzinga.com  2020-05-22 09:36:20-04:00     A
# 8          vishwanath@benzinga.com  2020-05-22 08:37:59-04:00     A
# 11         vishwanath@benzinga.com        2020-05-22 00:00:00     A
# 22         vishwanath@benzinga.com        2020-04-28 00:00:00     A
# ...                            ...                        ...   ...
# 1410564  bret.kenwell@benzinga.com        2013-04-24 00:00:00  ZNGA
# 1410565  bret.kenwell@benzinga.com        2013-04-24 00:00:00  ZNGA
# 1411299          luke@benzinga.com  2018-08-21 09:18:16-04:00  ZOES
# 1412846          luke@benzinga.com        2020-03-12 00:00:00  ZUMZ
# 1412847          luke@benzinga.com        2020-03-12 00:00:00  ZUMZ
#
#                                           cleaned_headline sentiment  \
# 5        cfra maintains hold agilent technologies lower...   Neutral
# 6        ubs maintains neutral agilent technologies rai...   Neutral
# 8        wells fargo maintains overweight agilent techn...   Neutral
# 11       svb leerink maintains outperform agilent techn...   Neutral
# 22       ubs maintains neutral agilent technologies low...   Neutral
# ...                                                    ...       ...
# 1410564  based options pricing 5 companies implied move...   Neutral
# 1410565  znga implied move 3 50 straddle price 0 50 14 ...   Neutral
# 1411299  zoe kitchen shares indicated 1 premarket light...  Positive
# 1412846  zumiez sees fy20 eps 0 01 0 07 vs 0 08 est sal...   Neutral
# 1412847  zumiez q4 eps 1 48 beats 1 36 estimate sales 3...   Neutral
#
#          polarity        domain
# 5        0.000000  benzinga.com
# 6        0.000000  benzinga.com
# 8        0.000000  benzinga.com
# 11       0.000000  benzinga.com
# 22       0.000000  benzinga.com
# ...           ...           ...
# 1410564  0.000000  benzinga.com
# 1410565  0.000000  benzinga.com
# 1411299  0.268182  benzinga.com
# 1412846  0.000000  benzinga.com
# 1412847  0.000000  benzinga.com
#
# [8088 rows x 9 columns]

# %% [markdown]
# ##### count articles that erouten by each domain

# %%
result.count_top_domains()
# Out:
#                    domain  count
# 0            benzinga.com   7937
# 1               gmail.com    139
# 2            andyswan.com      5
# 3          investdiva.com      2
# 4           tothetick.com      2
# 5           eosdetroit.io      1
# 6  forextraininggroup.com      1
# 7         stockmetrix.net      1

# %% [markdown]
# ##### plot email domain counts

# %%
result.plot_email_have_publisher()
